# %%
import plotly.io as pio

pio.renderers.default = "notebook_connected+plotly_mimetype"

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("EI-Stats-Review-ALL-data_2025.xlsx", na_values='..')
df.head
# Out:
# <bound method NDFrame.head of                                             Unnamed: 0
# 0    2025 Energy Institute Statistical Review of Wo...
# 1                                                  NaN
# 2    This workbook contains information presented i...
# 3    Energy Institute Statistical Review of World E...
# 4                                         internet at:
# ..                                                 ...
# 116  Primary Energy: Consumption by fuel type - Exa...
# 117                                                NaN
# 118                     Approximate conversion factors
# 119                                                NaN
# 120                                        Definitions
#
# [121 rows x 1 columns]>
